# %%
import os

path = "../dataset/original"

for cls in sorted(os.listdir(path)):
    print(cls, ":", len(os.listdir(os.path.join(path, cls))))
# Out:
# Bacterial_spot : 2127
# Early_blight : 1000
# Healthy : 1591
# Late_blight : 1909
# Leaf_Mold : 952
# MosaicVirus : 373
# Septoria_leaf_spot : 1771
# Spider_mites_Two_spotted_spider_mite : 1676
# Target_Spot : 1404
# YellowLeaf__Curl_Virus : 3209
